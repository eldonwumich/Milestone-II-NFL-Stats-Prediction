# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Import statements:

# %%
import pandas as pd

# %% [markdown]
# Searching for NA values:

# %%
# Defining a function that takes an input dataframe and outputs a df with the columns with NA values and their 
# corresponding counts.
def find_nas(df):
    counts = df.isna().sum()

    cols_with_none = []
    for col in counts.index:
        if counts[col] == 0:
            cols_with_none.append(col)

    output_df = pd.DataFrame(counts.drop(labels = cols_with_none)).T

    return output_df

# %% [markdown]
# Finding missing values where the missing value is denoted with a "0":

# %%
# Defining a function that will find counts of the number "0" in the kaggle data to help determine if the zeros may 
# represent missing values or special cases.
def find_zeros(df):
    counts = df.isin([0]).sum()

    cols_with_none = []
    for col in counts.index:
        if counts[col] == 0:
            cols_with_none.append(col)

    output_df = pd.DataFrame(counts.drop(labels = cols_with_none)).T

    return output_df

# %% [markdown]
# ### Evaluating weekly teams stats for vals missing:

# %%
# Loading in Data
weekly_team_stats_offense = pd.read_csv("Kaggle NFL CSVs/weekly_team_stats_offense.csv")
weekly_team_stats_defense = pd.read_csv("Kaggle NFL CSVs/weekly_team_stats_defense.csv")

# %%
# Check for NA values
display(find_nas(weekly_team_stats_offense))
display(find_nas(weekly_team_stats_defense))
# Out:
#    total_off_points  total_def_points
# 0                58                58
#    total_off_points  total_def_points
# 0                58                58

# %%
# Check for zero values:
off_weekly_team_zeros = find_zeros(weekly_team_stats_offense)
def_weekly_team_zeros = find_zeros(weekly_team_stats_defense)

display(off_weekly_team_zeros)
display(def_weekly_team_zeros)

# Print the column names for further details
print("Weekly Team Offense w/zeros:")
for col in off_weekly_team_zeros.columns:
    print(col)

print("\nWeekly Team Defense w/zeros:")
for col in def_weekly_team_zeros.columns:
    print(col)
# Out:
#    no_huddle  qb_scramble  incomplete_pass  tackled_for_loss  first_down_pass  \
# 0       1426         2076                1               757                1
#
#    first_down_rush  third_down_converted  fourth_down_converted  \
# 0               54                    48                   4080
#
#    fourth_down_failed  rush_touchdown  ...  average_fourth_down_failed  \
# 0                4212            2885  ...                         705
#
#    average_rush_touchdown  average_pass_touchdown  average_safety  \
# 0                     312                      86            5429
#
#    average_interception  average_fumble  average_fumble_lost  \
# 0                   368             180                  530
#
#    average_fumble_forced  average_fumble_not_forced  \
# 0                    321                        902
#
#    average_fumble_out_of_bounds
# 0                          3048
#
# [1 rows x 58 columns]
#    safety  interception  fumble  fumble_lost  fumble_forced  \
# 0    6870          3238    2102         4063           3112
#
#    fumble_not_forced  fumble_out_of_bounds  assist_tackle  tackle_with_assist  \
# 0               4781                  6362             36                2087
#
#    sack  ...  average_fumble_out_of_bounds  average_assist_tackle  \
# 0   861  ...                          2994                      2
#
#    average_tackle_with_assist  average_sack  average_qb_hit  \
# 0                         282            52               6
#
#    average_def_touchdown  average_defensive_two_point_attempt  \
# 0                   2775                                 6589
#
#    average_defensive_two_point_conv  average_defensive_extra_point_attempt  \
# 0                              6991                                   7088
#
#    average_defensive_extra_point_conv
# 0                                7088
#
# [1 rows x 49 columns]
# Weekly Team Offense w/zeros:
# no_huddle
# qb_scramble
# incomplete_pass
# tackled_for_loss
# first_down_pass
# first_down_rush
# third_down_converted
# fourth_down_converted
# fourth_down_failed
# rush_touchdown
# pass_touchdown
# safety
# interception
# fumble
# fumble_lost
# fumble_forced
# fumble_not_forced
# fumble_out_of_bounds
# total_def_points
# extra_point
# field_goal
# no_play
# punt
# qb_kneel
# qb_spike
# home_win
# home_loss
# home_tie
# away_win
# away_loss
# away_tie
# win
# loss
# tie
# win_pct
# receiving_touchdown
# int_pct
# pass_td_pct
# rec_td_pct
# rush_td_pct
# total_tds
# td_pct
# average_no_huddle
# average_qb_scramble
# average_tackled_for_loss
# average_first_down_rush
# average_third_down_converted
# average_fourth_down_converted
# average_fourth_down_failed
# average_rush_touchdown
# average_pass_touchdown
# average_safety
# average_interception
# average_fumble
# average_fumble_lost
# average_fumble_forced
# average_fumble_not_forced
# average_fumble_out_of_bounds
#
# Weekly Team Defense w/zeros:
# safety
# interception
# fumble
# fumble_lost
# fumble_forced
# fumble_not_forced
# fumble_out_of_bounds
# assist_tackle
# tackle_with_assist
# sack
# qb_hit
# def_touchdown
# defensive_two_point_attempt
# defensive_two_point_conv
# defensive_extra_point_attempt
# defensive_extra_point_conv
# total_def_points
# extra_point
# field_goal
# no_play
# punt
# qb_kneel
# qb_spike
# home_win
# home_loss
# home_tie
# away_win
# away_loss
# away_tie
# win
# loss
# tie
# win_pct
# average_safety
# average_interception
# average_fumble
# average_fumble_lost
# average_fumble_forced
# average_fumble_not_forced
# average_fumble_out_of_bounds
# average_assist_tackle
# average_tackle_with_assist
# average_sack
# average_qb_hit
# average_def_touchdown
# average_defensive_two_point_attempt
# average_defensive_two_point_conv
# average_defensive_extra_point_attempt
# average_defensive_extra_point_conv

# %%
# Count the number of rows in the dataframes for each regular season (to find if there are missing years)
# It should be 17 games x 32 teams = 544 rows for 2021 and after, and 16 games x 32 teams = 512 rows before.
# Also, in 2022 buffalo @ cincinatti was cancelled due to the injury of BUF safety Demar Hamlin.
regular_season_def = weekly_team_stats_defense["season_type"] == "REG"
regular_seaon_off = weekly_team_stats_offense["season_type"] == "REG"
display(weekly_team_stats_defense[regular_season_def]["season"].value_counts())
display(weekly_team_stats_offense[regular_seaon_off]["season"].value_counts())
# Out:
# season
# 2021    544
# 2023    544
# 2024    544
# 2022    542
# 2012    512
# 2013    512
# 2014    512
# 2015    512
# 2016    512
# 2017    512
# 2018    512
# 2019    512
# 2020    512
# Name: count, dtype: int64
# season
# 2021    544
# 2023    544
# 2024    544
# 2022    542
# 2012    512
# 2013    512
# 2014    512
# 2015    512
# 2016    512
# 2017    512
# 2018    512
# 2019    512
# 2020    512
# Name: count, dtype: int64

# %%
# Count the number of rows in the dataframes for the playoffs (to find if there are missing years)
# It should be 13 games * 2 teams = 26 rows per year 2020 and after, 11 games * 2 teams = 22 rows before.
postseason_def = weekly_team_stats_defense["season_type"] == "POST"
postseaon_off = weekly_team_stats_offense["season_type"] == "POST"
display(weekly_team_stats_defense[postseason_def]["season"].value_counts())
display(weekly_team_stats_offense[postseaon_off]["season"].value_counts())
# Out:
# season
# 2020    26
# 2021    26
# 2022    26
# 2023    26
# 2024    26
# 2012    22
# 2013    22
# 2014    22
# 2015    22
# 2016    22
# 2017    22
# 2018    22
# 2019    22
# Name: count, dtype: int64
# season
# 2020    26
# 2021    26
# 2022    26
# 2023    26
# 2024    26
# 2012    22
# 2013    22
# 2014    22
# 2015    22
# 2016    22
# 2017    22
# 2018    22
# 2019    22
# Name: count, dtype: int64

# %% [markdown]
# Investigating rows where total_off_points and total_def_points are missing values:

# %%
weekly_team_stats_offense["total_off_points"]
# Out:
# 0       20.0
# 1       20.0
# 2       21.0
# 3       24.0
# 4        3.0
#         ...
# 7083    30.0
# 7084    23.0
# 7085    23.0
# 7086    39.0
# 7087    23.0
# Name: total_off_points, Length: 7088, dtype: float64

# %%
# Get dfs where total_off_points and total_def_points are missing values:
pts_o = weekly_team_stats_offense["total_off_points"].isna() | weekly_team_stats_offense["total_def_points"].isna()
pts_d = weekly_team_stats_defense["total_off_points"].isna() | weekly_team_stats_defense["total_def_points"].isna()
missing_off_pts = weekly_team_stats_offense[pts_o]
missing_def_pts = weekly_team_stats_defense[pts_d]

display(missing_off_pts.head())
# display(missing_def_pts.head())
# Out:
#              game_id  season  week team season_type  shotgun  no_huddle  \
# 266   2012_15_KC_OAK    2012    15   KC         REG       27          3
# 332   2012_17_MIA_NE    2012    17  MIA         REG       44          9
# 397  2012_15_NYG_ATL    2012    15  NYG         REG       28          0
# 498    2012_15_TB_NO    2012    15   TB         REG       49          0
# 863  2013_16_MIA_BUF    2013    16  MIA         REG       48          1
#
#      qb_dropback  qb_scramble  total_off_yards  ...  \
# 266           36            0              146  ...
# 332           42            0              282  ...
# 397           26            0              258  ...
# 498           57            1              397  ...
# 863           40            0              149  ...
#
#      average_fourth_down_failed  average_rush_touchdown  \
# 266                    0.500000                0.714286
# 332                    0.625000                1.062500
# 397                    0.357143                1.214286
# 498                    0.428571                0.857143
# 863                    0.533333                0.533333
#
#      average_pass_touchdown  average_safety  average_interception  \
# 266                0.571429        0.000000              1.285714
# 332                0.812500        0.000000              0.812500
# 397                1.428571        0.000000              1.071429
# 498                1.785714        0.000000              0.857143
# 863                1.533333        0.066667              1.066667
#
#      average_fumble  average_fumble_lost  average_fumble_forced  \
# 266        1.714286             1.071429               1.142857
# 332        1.750000             0.687500               1.312500
# 397        1.071429             0.642857               0.714286
# 498        1.071429             0.428571               0.785714
# 863        1.200000             0.533333               0.733333
#
#      average_fumble_not_forced  average_fumble_out_of_bounds
# 266                   0.571429                      0.071429
# 332                   0.500000                      0.375000
# 397                   0.428571                      0.000000
# 498                   0.285714                      0.071429
# 863                   0.466667                      0.066667
#
# [5 rows x 115 columns]

# %%
# Compare game_ids where off/def points are missing.
def_ids = sorted(list(missing_def_pts["game_id"]))
off_ids = sorted(list(missing_off_pts["game_id"]))

print("off_id, def_id\n--------")
for off_id, def_id in zip(off_ids, def_ids):
    print(off_id, def_id)
# Out:
# off_id, def_id
# --------
# 2012_15_KC_OAK 2012_15_KC_OAK
# 2012_15_NYG_ATL 2012_15_NYG_ATL
# 2012_15_TB_NO 2012_15_TB_NO
# 2012_17_MIA_NE 2012_17_MIA_NE
# 2013_03_NYG_CAR 2013_03_NYG_CAR
# 2013_15_SEA_NYG 2013_15_SEA_NYG
# 2013_16_MIA_BUF 2013_16_MIA_BUF
# 2014_05_NYJ_SD 2014_05_NYJ_SD
# 2014_06_NYG_PHI 2014_06_NYG_PHI
# 2014_07_CIN_IND 2014_07_CIN_IND
# 2014_09_SD_MIA 2014_09_SD_MIA
# 2014_15_CIN_CLE 2014_15_CIN_CLE
# 2015_03_CHI_SEA 2015_03_CHI_SEA
# 2015_14_ATL_CAR 2015_14_ATL_CAR
# 2015_18_KC_HOU 2015_18_KC_HOU
# 2016_01_LA_SF 2016_01_LA_SF
# 2016_03_HOU_NE 2016_03_HOU_NE
# 2016_04_BUF_NE 2016_04_BUF_NE
# 2017_01_BAL_CIN 2017_01_BAL_CIN
# 2017_04_NO_MIA 2017_04_NO_MIA
# 2017_07_ARI_LA 2017_07_ARI_LA
# 2017_07_JAX_IND 2017_07_JAX_IND
# 2017_11_BAL_GB 2017_11_BAL_GB
# 2017_14_NYJ_DEN 2017_14_NYJ_DEN
# 2017_16_MIN_GB 2017_16_MIN_GB
# 2017_17_DAL_PHI 2017_17_DAL_PHI
# 2018_02_ARI_LA 2018_02_ARI_LA
# 2018_04_BUF_GB 2018_04_BUF_GB
# 2018_06_BAL_TEN 2018_06_BAL_TEN
# 2018_13_IND_JAX 2018_13_IND_JAX
# 2018_15_DAL_IND 2018_15_DAL_IND
# 2018_15_TEN_NYG 2018_15_TEN_NYG
# 2018_17_DET_GB 2018_17_DET_GB
# 2018_17_PHI_WAS 2018_17_PHI_WAS
# 2019_06_TEN_DEN 2019_06_TEN_DEN
# 2019_07_NE_NYJ 2019_07_NE_NYJ
# 2019_07_SF_WAS 2019_07_SF_WAS
# 2020_06_NYJ_MIA 2020_06_NYJ_MIA
# 2020_11_DET_CAR 2020_11_DET_CAR
# 2021_02_BUF_MIA 2021_02_BUF_MIA
# 2021_03_NYJ_DEN 2021_03_NYJ_DEN
# 2021_04_HOU_BUF 2021_04_HOU_BUF
# 2021_10_SEA_GB 2021_10_SEA_GB
# 2021_13_IND_HOU 2021_13_IND_HOU
# 2021_14_JAX_TEN 2021_14_JAX_TEN
# 2021_15_NO_TB 2021_15_NO_TB
# 2022_02_IND_JAX 2022_02_IND_JAX
# 2022_08_LV_NO 2022_08_LV_NO
# 2022_12_NO_SF 2022_12_NO_SF
# 2023_09_ARI_CLE 2023_09_ARI_CLE
# 2023_13_LAC_NE 2023_13_LAC_NE
# 2023_14_MIN_LV 2023_14_MIN_LV
# 2023_15_NYJ_MIA 2023_15_NYJ_MIA
# 2023_17_CAR_JAX 2023_17_CAR_JAX
# 2023_18_TB_CAR 2023_18_TB_CAR
# 2024_16_NO_GB 2024_16_NO_GB
# 2024_17_BAL_HOU 2024_17_BAL_HOU
# 2024_18_KC_DEN 2024_18_KC_DEN

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=32f663d2-ff71-4fff-a76e-068fa019f967' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
